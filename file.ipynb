# %%
import pytesseract

# %%
import cv2 # pip install opencv-python

# %%
import pytesseract as pya

# %%
import matplotlib.pyplot as plt ## pip install matplotlib

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import re

# %%
img = cv2.imread('demo123.jpg')

# %%
#mport cv2 ### pip install opencv-python
## pip install opencv-contrib-python fullpackage
import re
import time
import psutil
import matplotlib.pyplot as plt
#mport numpy as np
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN
cap = cv2.VideoCapture(1)
#cap = cv2.VideoCapture("demovideo.wmv")
cap.set(3, 640)
cap.set(4, 480)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
cntr =0;
while True:
    ret,frame = cap.read()

    cntr= cntr+1;
    if ((cntr%100)==0):
        #type(imgboxes)
        imgH, imgW,_ = frame.shape
        # eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')
        x1,y1,w1,h1 = 0,0,imgH,imgW
        #img3char = pytesseract.image_to_string(frame)
        #imgchar = re.sub('\D', ' ', img3char)
        img3char = pytesseract.image_to_string(frame)
        img4char = img3char.replace(",", "")
        imgchar = re.sub('\D', ' ', img4char)
       
    
        #imgchar = pytesseract.image_to_string(frame)
        print (img4char)
        number_list = imgchar.split()
        #chọn vị trí chuỗi con 1
        sub_list_11 = number_list[:1]
        if sub_list_11:
            sub_list_1 = sub_list_11
        else:
            sub_list_1 = "0"        
       
        #chọn vị trí chuỗi con 2
        sub_list_21 = number_list[1:2]
        if sub_list_21:
            sub_list_2 = sub_list_21
        else:
            sub_list_2 = "0"   
       
         #chọn vị trí chuỗi con 3
        sub_list_31 = number_list[2:3]
        if sub_list_31:
            sub_list_3 = sub_list_31
        else:
            sub_list_3 = "0"        
        
         #chọn vị trí chuỗi con 4
        sub_list_41 = number_list[3:4]
        if sub_list_41:
            sub_list_4 = sub_list_41
        else:
            sub_list_4 = "0"
        
        #chuyển 2 chuỗi con thành số nguyên      
        ncden1 = int(float(sub_list_1[0]))
        if ncden1 > 0:
            ncden = ncden1
        if ncden1 <= 0:
            ncden = "-1"
        if int(ncden) > 5000:
            bdncden = 5000
        if int(ncden) < 5000:
            bdncden = ncden 
        if int(ncden) < 0:
            bdncden = "0"
        
        nctrang1 = int(float(sub_list_2[0]))
        if nctrang1 > 0:
            nctrang = nctrang1
        if nctrang1 <= 0:
            nctrang = "-1"
        if int(nctrang) > 5000:
            bdnctrang = 5000
        if int(nctrang) < 5000:
            bdnctrang = nctrang
        if int(nctrang) < 0:
            bdnctrang = "0"
        
        tienden1 = int(float(sub_list_3[0]))
        if tienden1 > 0:
            tienden = tienden1
        if tienden1 <= 0:
            tienden = "-1"        
        
        tientrang1 = int(float(sub_list_4[0]))
        if tientrang1 > 0:
            tientrang = tientrang1
        if tientrang1 <= 0:
            tientrang = "-1"        
        
        trungbinhden = int(tienden) / int(ncden)
        if int(trungbinhden) > 2000000:
            bdtrungbinhden = "2000"
        if int(trungbinhden) < 2000000:
            bdtrungbinhden = int(trungbinhden)/1000
        if int(trungbinhden) < 0:
            bdtrungbinhden = "0"
        trungbinhtrang = int(tientrang) / int(nctrang)
        if int(trungbinhtrang) > 2000000:
            bdtrungbinhtrang = "2000"
        if int(trungbinhtrang) < 2000000:
            bdtrungbinhtrang = int(trungbinhtrang)/1000
        if int(trungbinhtrang) < 0:
            bdtrungbinhtrang = "0"
        
        chenhlechnc = int(ncden) - int(nctrang)
        ketqua = 'TBT' + ':' + str(round(trungbinhden)) + ' ' + 'TBX' + ':' + str(round(trungbinhtrang)) + ' ' + 'HNC' + ':' +str(round(chenhlechnc))
        ketqua1 = 'NCT' + ':' + str(ncden) + ' ' + 'NCX' + ':' + str(nctrang) + ' ' + 'TT' + ':' + str(tienden) + ' ' + 'TX' + ':' + str(tientrang)
        ## Hien thi tren bieu do
        
    
                       
    #het thu nghiem
        
        imgboxes = pytesseract.image_to_boxes(frame)
        for boxes in imgboxes.splitlines():
            boxes= boxes.split(' ')
            x,y,w,h = int(boxes[1]),int(boxes[2]),int(boxes[3]),int(boxes[4])
            cv2.rectangle(img, (x,imgH-y), (w,imgH-h), (0,0,255),3)
        #cv2.rectangle(frame,(x1, x1), (x1 + w1, y1 + h1), (0,0,0), -1)

        # Add text
        cv2.putText(frame, ketqua, (50,200), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        cv2.putText(frame, ketqua1, (50,250), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        font = cv2.FONT_HERSHEY_SIMPLEX
        
        #########
        cv2.imshow('Thu Nghiem',frame)
        if cv2.waitKey(2) & 0xFF == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Please launch SparkoCam
# to activate this webcam
#
# Lg
#
# ka
#
# http://sparkosoft.com
#
# Please launch SparkoCam
# to activate this webcam
#
# Lg
#
# ka
#
# http://sparkosoft.com
#
# Please launch SparkoCam
# to activate this webcam
#
# Lg
#
# ka
#
# http://sparkosoft.com
#
# Please launch SparkoCam
# to activate this webcam
#
# Lg
#
# ka
#
# http://sparkosoft.com
#
# Please launch SparkoCam
# to activate this webcam
#
# Lg
#
# ka
#
# http://sparkosoft.com
